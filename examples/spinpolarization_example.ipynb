# %% [markdown]
# # ABEL spin polarization example
#
# By Eir E. Hørlyk (University of Oslo), 6 Mar 2025

# %% [markdown]
# ### Import ABEL framework

# %%
from abel import *
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/eirhorlyk/.abelconfig.toml
# Loading ABEL config from '/Users/eirhorlyk/.abelconfig.toml'
# CONFIG.cluster_name = "LOCAL"
# CONFIG.default_cmap = <matplotlib.colors.ListedColormap object at 0x13e83b450>
# CONFIG.elegant_exec = "/Users/eirhorlyk/code/elegant/bin/"
# CONFIG.elegant_path = "/Users/eirhorlyk/code/elegant/bin/"
# CONFIG.elegant_rpnflag = " -rpnDefns=/Users/eirhorlyk/code/elegant/bin/defns.rpn"
# CONFIG.elegant_use_container = False
# CONFIG.guineapig_path = "/Users/eirhorlyk/code/guineapig/bin"
# CONFIG.hipace_binary = "/Users/eirhorlyk/code/hipace/build/bin/hipace"
# CONFIG.hipace_path = "/Users/eirhorlyk/code/hipace"
# CONFIG.partition_name_small = ""
# CONFIG.partition_name_standard = ""
# CONFIG.plot_fullwidth_default = 18
# CONFIG.plot_width_default = 8
# CONFIG.project_name = ""
# CONFIG.run_data_path = "run_data/"
# CONFIG.software_path = "/Users/eirhorlyk/code"
# CONFIG.temp_path = "run_data/temp/"
# Could not import HiPACE++ tools from /Users/eirhorlyk/code/hipace/tools

# %% [markdown]
# ### Define the linac and beams

# %%
# define beam
source = SourceBasic()
source.charge = -1e10 * SI.e # [C]
source.energy = 5e9 # [eV]
source.rel_energy_spread = 0.01
source.bunch_length = 18e-6 # [m]
source.z_offset = -36e-6 # [m]
source.emit_nx, source.emit_ny = 160e-6, 0.56e-6 # [m rad]
source.beta_x = 1
source.beta_y = source.beta_x
source.num_particles = 1000000

# %% [markdown]
# ### Run simulations

# %%
beam = source.track()
#beam.set_spin_unpolarized()
beam.set_arbitrary_spin_polarization(0.85, 'z')
beam.plot_spins()

# %%
beam.plot_spins_2D()

# %%
beam.plot_spins_3D()
