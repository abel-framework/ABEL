# %%
import sys
sys.path.append('../')
from opal import Linac, Collider
from opal import SourceBasic, StageNonlinear1D, InterstageELEGANT, InterstageBasic, BeamDeliverySystemBasic, InteractionPointGUINEAPIG
from opal.utilities.plasmaphysics import beta_matched
import numpy as np

# define driver
driver = SourceBasic()
driver.Q = -5e-9 # [C]
driver.E0 = 38e9 # [eV]
driver.relsigE = 0.01
driver.sigz = 20e-6 # [m]
driver.z = 120e-6 # [m]
driver.emitnx, driver.emitny = 10e-6, 10e-6 # [m rad]
driver.betax, driver.betay = 30e-3, 30e-3 # [m]
driver.Npart = 2000
driver.wallplugEfficiency = 0.5
driver.jitter.t0 = 5e-15 # [s]
driver.jitter.x0, driver.jitter.y0 = 50e-9, 50e-9# [m]
driver.acceleratingGradient = 25e6 # [V/m]

# define stage
stage = StageNonlinear1D()
stage.driverSource = driver
stage.deltaE = 25e9 # [eV]
stage.L = 4.25 # [m]
stage.n0 = 2e22 # [m^-3]
stage.reljitter.n0 = 0.01
stage.enableBetatron = True

# define beam
source = SourceBasic()
#source.L = 10 # [m]
source.Q = -2.7e-9 # [C]
source.E0 = 3e9 # [eV]
source.relsigE = 0.005
source.sigz = 12e-6 # [m]
source.z = -60e-6 # [m]
source.emitnx = 10e-6 # [m rad]
source.emitny = 0.035e-6 # [m rad]
source.betax = beta_matched(stage.n0, source.E0) # [m]
source.betay = source.betax
source.Npart = 500
source.wallplugEfficiency = 0.1
source.jitter.t0 = 5e-15 # [s]
source.jitter.x0, source.jitter.y0 = 50e-9, 50e-9 # [m]
source.acceleratingGradient = 25e6 # [V/m]

# define interstage
#interstage = InterstageELEGANT()
interstage = InterstageBasic()
interstage.beta0 = lambda E: beta_matched(stage.n0, E) # [T]
interstage.Bdip = 0.5 # [T]
interstage.Ldip = lambda E: 1 * np.sqrt(E/10e9) # [m(eV)]
interstage.enableISR = True
interstage.enableCSR = False

# beam delivery system
bds = BeamDeliverySystemBasic()
bds.beta_waist_x = 8e-3 # [m]
bds.beta_waist_y = 0.4e-3 # [m]
#bds.L = 20 # [m]

# define linac
linac = Linac(source, stage, interstage, bds, Nstages = 60, alternatingInterstagePolarity=False)

# define interaction point
ip = InteractionPointGUINEAPIG()

# define collider
collider = Collider(linac, ip)

# track particles
collider.run("high-energy-collider_test", shots=3, overwrite=True)

# plot survery and beam evolution
print(f"COST: {collider.constructionCost()/1e9:.2f} (construction) + {collider.runningCost()/1e9:.2f} (running) = {collider.totalCost()/1e9:.2f} billion LCU")
collider.plotLuminosity()
collider.plotLuminosityPerPower()
linac.plotEvolution(useStageNumbers=True)
linac.plotWaterfalls()
linac.plotSurvey()
stage.plotWakefield(linac.initialBeam())
stage.plotWakefield(linac.finalBeam())
# Out:
# >> LINAC #1
# >> SHOT #1
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# Tracking element #2 (s = 124.2 m, -2.70 nC, 26.6 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 26.6 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 51.2 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 51.2 GeV, InterstageBasic, stage 2)
# Tracking element #6 (s = 151.8 m, -2.70 nC, 76.0 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 76.0 GeV, InterstageBasic, stage 3)
# Tracking element #8 (s = 169.4 m, -2.70 nC, 102.4 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 102.4 GeV, InterstageBasic, stage 4)
# Tracking element #10 (s = 189.0 m, -2.70 nC, 127.4 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 127.4 GeV, InterstageBasic, stage 5)
# Tracking element #12 (s = 210.4 m, -2.70 nC, 152.5 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 152.5 GeV, InterstageBasic, stage 6)
# Tracking element #14 (s = 233.4 m, -2.70 nC, 177.3 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 177.3 GeV, InterstageBasic, stage 7)
# Tracking element #16 (s = 257.8 m, -2.70 nC, 203.3 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 203.3 GeV, InterstageBasic, stage 8)
# WARNING: 1.7% of driver particles were energy depleted.
# Tracking element #18 (s = 283.6 m, -2.70 nC, 228.2 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 228.2 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 254.7 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 254.7 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 280.8 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 280.8 GeV, InterstageBasic, stage 11)
# WARNING: 0.8% of driver particles were energy depleted.
# Tracking element #24 (s = 368.6 m, -2.70 nC, 307.0 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 307.0 GeV, InterstageBasic, stage 12)
# WARNING: 14.6% of driver particles were energy depleted.
# Tracking element #26 (s = 399.2 m, -2.70 nC, 329.5 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 329.5 GeV, InterstageBasic, stage 13)
# Tracking element #28 (s = 430.8 m, -2.70 nC, 355.4 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 355.4 GeV, InterstageBasic, stage 14)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #30 (s = 463.5 m, -2.70 nC, 382.8 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 382.8 GeV, InterstageBasic, stage 15)
# Tracking element #32 (s = 497.2 m, -2.70 nC, 406.6 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 406.6 GeV, InterstageBasic, stage 16)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #34 (s = 531.9 m, -2.70 nC, 430.1 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 430.1 GeV, InterstageBasic, stage 17)
# Tracking element #36 (s = 567.4 m, -2.70 nC, 454.3 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 454.3 GeV, InterstageBasic, stage 18)
# WARNING: 0.9% of driver particles were energy depleted.
# Tracking element #38 (s = 603.9 m, -2.70 nC, 480.0 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 480.0 GeV, InterstageBasic, stage 19)
# WARNING: 2.4% of driver particles were energy depleted.
# Tracking element #40 (s = 641.3 m, -2.70 nC, 505.0 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 505.0 GeV, InterstageBasic, stage 20)
# WARNING: 7.4% of driver particles were energy depleted.
# Tracking element #42 (s = 679.5 m, -2.70 nC, 528.6 GeV, StageNonlinear1D, stage 21)
# Tracking element #43 (s = 714.3 m, -2.70 nC, 528.6 GeV, InterstageBasic, stage 21)
# WARNING: 9.3% of driver particles were energy depleted.
# Tracking element #44 (s = 718.5 m, -2.70 nC, 553.7 GeV, StageNonlinear1D, stage 22)
# Tracking element #45 (s = 754.1 m, -2.70 nC, 553.7 GeV, InterstageBasic, stage 22)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #46 (s = 758.4 m, -2.70 nC, 578.9 GeV, StageNonlinear1D, stage 23)
# Tracking element #47 (s = 794.8 m, -2.70 nC, 578.9 GeV, InterstageBasic, stage 23)
# Tracking element #48 (s = 799.0 m, -2.70 nC, 604.9 GeV, StageNonlinear1D, stage 24)
# Tracking element #49 (s = 836.2 m, -2.70 nC, 604.9 GeV, InterstageBasic, stage 24)
# Tracking element #50 (s = 840.4 m, -2.70 nC, 629.3 GeV, StageNonlinear1D, stage 25)
# Tracking element #51 (s = 878.4 m, -2.70 nC, 629.3 GeV, InterstageBasic, stage 25)
# WARNING: 0.8% of driver particles were energy depleted.
# Tracking element #52 (s = 882.6 m, -2.70 nC, 654.2 GeV, StageNonlinear1D, stage 26)
# Tracking element #53 (s = 921.3 m, -2.70 nC, 654.2 GeV, InterstageBasic, stage 26)
# Tracking element #54 (s = 925.6 m, -2.70 nC, 678.0 GeV, StageNonlinear1D, stage 27)
# Tracking element #55 (s = 965.0 m, -2.70 nC, 678.0 GeV, InterstageBasic, stage 27)
# Tracking element #56 (s = 969.2 m, -2.70 nC, 701.6 GeV, StageNonlinear1D, stage 28)
# Tracking element #57 (s = 1009.4 m, -2.70 nC, 701.6 GeV, InterstageBasic, stage 28)
# Tracking element #58 (s = 1013.6 m, -2.70 nC, 726.3 GeV, StageNonlinear1D, stage 29)
# Tracking element #59 (s = 1054.5 m, -2.70 nC, 726.3 GeV, InterstageBasic, stage 29)
# Tracking element #60 (s = 1058.7 m, -2.70 nC, 751.7 GeV, StageNonlinear1D, stage 30)
# Tracking element #61 (s = 1100.3 m, -2.70 nC, 751.7 GeV, InterstageBasic, stage 30)
# Tracking element #62 (s = 1104.5 m, -2.70 nC, 776.0 GeV, StageNonlinear1D, stage 31)
# Tracking element #63 (s = 1146.7 m, -2.70 nC, 776.0 GeV, InterstageBasic, stage 31)
# Tracking element #64 (s = 1151.0 m, -2.70 nC, 801.2 GeV, StageNonlinear1D, stage 32)
# Tracking element #65 (s = 1193.9 m, -2.70 nC, 801.2 GeV, InterstageBasic, stage 32)
# Tracking element #66 (s = 1198.1 m, -2.70 nC, 826.2 GeV, StageNonlinear1D, stage 33)
# Tracking element #67 (s = 1241.7 m, -2.70 nC, 826.2 GeV, InterstageBasic, stage 33)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #68 (s = 1245.9 m, -2.70 nC, 851.6 GeV, StageNonlinear1D, stage 34)
# Tracking element #69 (s = 1290.2 m, -2.70 nC, 851.6 GeV, InterstageBasic, stage 34)
# Tracking element #70 (s = 1294.4 m, -2.70 nC, 877.4 GeV, StageNonlinear1D, stage 35)
# Tracking element #71 (s = 1339.3 m, -2.70 nC, 877.4 GeV, InterstageBasic, stage 35)
# Tracking element #72 (s = 1343.5 m, -2.70 nC, 902.7 GeV, StageNonlinear1D, stage 36)
# Tracking element #73 (s = 1389.0 m, -2.70 nC, 902.7 GeV, InterstageBasic, stage 36)
# Tracking element #74 (s = 1393.3 m, -2.70 nC, 928.5 GeV, StageNonlinear1D, stage 37)
# Tracking element #75 (s = 1439.4 m, -2.70 nC, 928.5 GeV, InterstageBasic, stage 37)
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 953.1 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 953.1 GeV, InterstageBasic, stage 38)
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 978.1 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 978.1 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 1004.3 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 1004.3 GeV, InterstageBasic, stage 40)
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1029.7 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1029.7 GeV, InterstageBasic, stage 41)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1055.3 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1055.3 GeV, InterstageBasic, stage 42)
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1079.2 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1079.2 GeV, InterstageBasic, stage 43)
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1103.1 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1103.1 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1128.7 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1128.7 GeV, InterstageBasic, stage 45)
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1154.4 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1154.4 GeV, InterstageBasic, stage 46)
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1179.8 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1179.8 GeV, InterstageBasic, stage 47)
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1205.2 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1205.2 GeV, InterstageBasic, stage 48)
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1229.7 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1229.7 GeV, InterstageBasic, stage 49)
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1254.6 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1254.6 GeV, InterstageBasic, stage 50)
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1279.9 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1279.9 GeV, InterstageBasic, stage 51)
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1302.9 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1302.9 GeV, InterstageBasic, stage 52)
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1326.7 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1326.7 GeV, InterstageBasic, stage 53)
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1349.4 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1349.4 GeV, InterstageBasic, stage 54)
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1375.2 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1375.2 GeV, InterstageBasic, stage 55)
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1402.2 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1402.2 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1426.2 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1426.2 GeV, InterstageBasic, stage 57)
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1450.9 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1450.9 GeV, InterstageBasic, stage 58)
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1477.6 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1477.6 GeV, InterstageBasic, stage 59)
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1502.5 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1502.5 GeV, BeamDeliverySystemBasic, stage 60)
# >> SHOT #2
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# Tracking element #2 (s = 124.2 m, -2.70 nC, 25.5 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 25.5 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 52.0 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 52.0 GeV, InterstageBasic, stage 2)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #6 (s = 151.8 m, -2.70 nC, 79.7 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 79.7 GeV, InterstageBasic, stage 3)
# Tracking element #8 (s = 169.4 m, -2.70 nC, 104.6 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 104.6 GeV, InterstageBasic, stage 4)
# Tracking element #10 (s = 189.0 m, -2.70 nC, 131.2 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 131.2 GeV, InterstageBasic, stage 5)
# Tracking element #12 (s = 210.4 m, -2.70 nC, 157.0 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 157.0 GeV, InterstageBasic, stage 6)
# WARNING: 1.5% of driver particles were energy depleted.
# Tracking element #14 (s = 233.4 m, -2.70 nC, 184.3 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 184.3 GeV, InterstageBasic, stage 7)
# Tracking element #16 (s = 257.8 m, -2.70 nC, 210.1 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 210.1 GeV, InterstageBasic, stage 8)
# Tracking element #18 (s = 283.6 m, -2.70 nC, 234.2 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 234.2 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 258.5 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 258.5 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 282.1 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 282.1 GeV, InterstageBasic, stage 11)
# Tracking element #24 (s = 368.6 m, -2.70 nC, 308.4 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 308.4 GeV, InterstageBasic, stage 12)
# Tracking element #26 (s = 399.2 m, -2.70 nC, 333.7 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 333.7 GeV, InterstageBasic, stage 13)
# WARNING: 0.3% of driver particles were energy depleted.
# Tracking element #28 (s = 430.8 m, -2.70 nC, 358.1 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 358.1 GeV, InterstageBasic, stage 14)
# WARNING: 0.2% of driver particles were energy depleted.
# Tracking element #30 (s = 463.5 m, -2.70 nC, 382.8 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 382.8 GeV, InterstageBasic, stage 15)
# Tracking element #32 (s = 497.2 m, -2.70 nC, 407.6 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 407.6 GeV, InterstageBasic, stage 16)
# Tracking element #34 (s = 531.9 m, -2.70 nC, 430.2 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 430.2 GeV, InterstageBasic, stage 17)
# Tracking element #36 (s = 567.4 m, -2.70 nC, 454.7 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 454.7 GeV, InterstageBasic, stage 18)
# Tracking element #38 (s = 603.9 m, -2.70 nC, 479.4 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 479.4 GeV, InterstageBasic, stage 19)
# Tracking element #40 (s = 641.3 m, -2.70 nC, 502.0 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 502.0 GeV, InterstageBasic, stage 20)
# Tracking element #42 (s = 679.5 m, -2.70 nC, 525.3 GeV, StageNonlinear1D, stage 21)
# Tracking element #43 (s = 714.3 m, -2.70 nC, 525.3 GeV, InterstageBasic, stage 21)
# Tracking element #44 (s = 718.5 m, -2.70 nC, 549.4 GeV, StageNonlinear1D, stage 22)
# Tracking element #45 (s = 754.1 m, -2.70 nC, 549.4 GeV, InterstageBasic, stage 22)
# Tracking element #46 (s = 758.4 m, -2.70 nC, 572.9 GeV, StageNonlinear1D, stage 23)
# Tracking element #47 (s = 794.8 m, -2.70 nC, 572.9 GeV, InterstageBasic, stage 23)
# Tracking element #48 (s = 799.0 m, -2.70 nC, 593.8 GeV, StageNonlinear1D, stage 24)
# Tracking element #49 (s = 836.2 m, -2.70 nC, 593.8 GeV, InterstageBasic, stage 24)
# WARNING: 0.9% of driver particles were energy depleted.
# Tracking element #50 (s = 840.4 m, -2.70 nC, 618.0 GeV, StageNonlinear1D, stage 25)
# Tracking element #51 (s = 878.4 m, -2.70 nC, 618.0 GeV, InterstageBasic, stage 25)
# Tracking element #52 (s = 882.6 m, -2.70 nC, 641.2 GeV, StageNonlinear1D, stage 26)
# Tracking element #53 (s = 921.3 m, -2.70 nC, 641.2 GeV, InterstageBasic, stage 26)
# Tracking element #54 (s = 925.6 m, -2.70 nC, 664.6 GeV, StageNonlinear1D, stage 27)
# Tracking element #55 (s = 965.0 m, -2.70 nC, 664.6 GeV, InterstageBasic, stage 27)
# WARNING: 16.6% of driver particles were energy depleted.
# Tracking element #56 (s = 969.2 m, -2.70 nC, 689.4 GeV, StageNonlinear1D, stage 28)
# Tracking element #57 (s = 1009.4 m, -2.70 nC, 689.4 GeV, InterstageBasic, stage 28)
# Tracking element #58 (s = 1013.6 m, -2.70 nC, 713.7 GeV, StageNonlinear1D, stage 29)
# Tracking element #59 (s = 1054.5 m, -2.70 nC, 713.7 GeV, InterstageBasic, stage 29)
# Tracking element #60 (s = 1058.7 m, -2.70 nC, 737.9 GeV, StageNonlinear1D, stage 30)
# Tracking element #61 (s = 1100.3 m, -2.70 nC, 737.9 GeV, InterstageBasic, stage 30)
# Tracking element #62 (s = 1104.5 m, -2.70 nC, 763.8 GeV, StageNonlinear1D, stage 31)
# Tracking element #63 (s = 1146.7 m, -2.70 nC, 763.8 GeV, InterstageBasic, stage 31)
# Tracking element #64 (s = 1151.0 m, -2.70 nC, 789.4 GeV, StageNonlinear1D, stage 32)
# Tracking element #65 (s = 1193.9 m, -2.70 nC, 789.4 GeV, InterstageBasic, stage 32)
# Tracking element #66 (s = 1198.1 m, -2.70 nC, 813.0 GeV, StageNonlinear1D, stage 33)
# Tracking element #67 (s = 1241.7 m, -2.70 nC, 813.0 GeV, InterstageBasic, stage 33)
# WARNING: 45.1% of driver particles were energy depleted.
# Tracking element #68 (s = 1245.9 m, -2.70 nC, 836.5 GeV, StageNonlinear1D, stage 34)
# Tracking element #69 (s = 1290.2 m, -2.70 nC, 836.5 GeV, InterstageBasic, stage 34)
# WARNING: 1.8% of driver particles were energy depleted.
# Tracking element #70 (s = 1294.4 m, -2.70 nC, 861.0 GeV, StageNonlinear1D, stage 35)
# Tracking element #71 (s = 1339.3 m, -2.70 nC, 861.0 GeV, InterstageBasic, stage 35)
# WARNING: 32.5% of driver particles were energy depleted.
# Tracking element #72 (s = 1343.5 m, -2.70 nC, 883.9 GeV, StageNonlinear1D, stage 36)
# Tracking element #73 (s = 1389.0 m, -2.70 nC, 883.9 GeV, InterstageBasic, stage 36)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #74 (s = 1393.3 m, -2.70 nC, 907.6 GeV, StageNonlinear1D, stage 37)
# Tracking element #75 (s = 1439.4 m, -2.70 nC, 907.6 GeV, InterstageBasic, stage 37)
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 931.2 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 931.2 GeV, InterstageBasic, stage 38)
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 955.2 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 955.2 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 979.7 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 979.7 GeV, InterstageBasic, stage 40)
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1005.3 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1005.3 GeV, InterstageBasic, stage 41)
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1029.0 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1029.0 GeV, InterstageBasic, stage 42)
# WARNING: 1.7% of driver particles were energy depleted.
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1055.2 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1055.2 GeV, InterstageBasic, stage 43)
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1079.5 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1079.5 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1105.1 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1105.1 GeV, InterstageBasic, stage 45)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1131.3 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1131.3 GeV, InterstageBasic, stage 46)
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1157.3 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1157.3 GeV, InterstageBasic, stage 47)
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1183.2 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1183.2 GeV, InterstageBasic, stage 48)
# WARNING: 6.1% of driver particles were energy depleted.
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1209.9 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1209.9 GeV, InterstageBasic, stage 49)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1236.3 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1236.3 GeV, InterstageBasic, stage 50)
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1262.4 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1262.4 GeV, InterstageBasic, stage 51)
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1287.9 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1287.9 GeV, InterstageBasic, stage 52)
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1313.3 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1313.3 GeV, InterstageBasic, stage 53)
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1338.9 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1338.9 GeV, InterstageBasic, stage 54)
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1364.6 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1364.6 GeV, InterstageBasic, stage 55)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1390.0 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1390.0 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1416.3 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1416.3 GeV, InterstageBasic, stage 57)
# WARNING: 4.7% of driver particles were energy depleted.
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1442.5 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1442.5 GeV, InterstageBasic, stage 58)
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1469.2 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1469.2 GeV, InterstageBasic, stage 59)
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1494.8 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1494.8 GeV, BeamDeliverySystemBasic, stage 60)
# >> SHOT #3
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# WARNING: 0.2% of driver particles were energy depleted.
# Tracking element #2 (s = 124.2 m, -2.70 nC, 29.5 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 29.5 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 53.2 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 53.2 GeV, InterstageBasic, stage 2)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #6 (s = 151.8 m, -2.70 nC, 78.1 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 78.1 GeV, InterstageBasic, stage 3)
# Tracking element #8 (s = 169.4 m, -2.70 nC, 102.5 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 102.5 GeV, InterstageBasic, stage 4)
# Tracking element #10 (s = 189.0 m, -2.70 nC, 126.4 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 126.4 GeV, InterstageBasic, stage 5)
# Tracking element #12 (s = 210.4 m, -2.70 nC, 150.4 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 150.4 GeV, InterstageBasic, stage 6)
# Tracking element #14 (s = 233.4 m, -2.70 nC, 175.1 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 175.1 GeV, InterstageBasic, stage 7)
# Tracking element #16 (s = 257.8 m, -2.70 nC, 199.5 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 199.5 GeV, InterstageBasic, stage 8)
# Tracking element #18 (s = 283.6 m, -2.70 nC, 225.1 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 225.1 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 252.9 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 252.9 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 278.2 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 278.2 GeV, InterstageBasic, stage 11)
# Tracking element #24 (s = 368.6 m, -2.70 nC, 304.0 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 304.0 GeV, InterstageBasic, stage 12)
# Tracking element #26 (s = 399.2 m, -2.70 nC, 329.8 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 329.8 GeV, InterstageBasic, stage 13)
# Tracking element #28 (s = 430.8 m, -2.70 nC, 355.0 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 355.0 GeV, InterstageBasic, stage 14)
# Tracking element #30 (s = 463.5 m, -2.70 nC, 381.3 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 381.3 GeV, InterstageBasic, stage 15)
# Tracking element #32 (s = 497.2 m, -2.70 nC, 407.2 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 407.2 GeV, InterstageBasic, stage 16)
# WARNING: 6.3% of driver particles were energy depleted.
# Tracking element #34 (s = 531.9 m, -2.70 nC, 430.5 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 430.5 GeV, InterstageBasic, stage 17)
# WARNING: 7.8% of driver particles were energy depleted.
# Tracking element #36 (s = 567.4 m, -2.70 nC, 454.7 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 454.7 GeV, InterstageBasic, stage 18)
# Tracking element #38 (s = 603.9 m, -2.70 nC, 480.2 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 480.2 GeV, InterstageBasic, stage 19)
# Tracking element #40 (s = 641.3 m, -2.70 nC, 507.5 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 507.5 GeV, InterstageBasic, stage 20)
# WARNING: 51.3% of driver particles were energy depleted.
# Tracking element #42 (s = 679.5 m, -2.70 nC, 532.2 GeV, StageNonlinear1D, stage 21)
# Tracking element #43 (s = 714.3 m, -2.70 nC, 532.2 GeV, InterstageBasic, stage 21)
# Tracking element #44 (s = 718.5 m, -2.70 nC, 557.2 GeV, StageNonlinear1D, stage 22)
# Tracking element #45 (s = 754.1 m, -2.70 nC, 557.2 GeV, InterstageBasic, stage 22)
# Tracking element #46 (s = 758.4 m, -2.70 nC, 580.5 GeV, StageNonlinear1D, stage 23)
# Tracking element #47 (s = 794.8 m, -2.70 nC, 580.5 GeV, InterstageBasic, stage 23)
# Tracking element #48 (s = 799.0 m, -2.70 nC, 605.3 GeV, StageNonlinear1D, stage 24)
# Tracking element #49 (s = 836.2 m, -2.70 nC, 605.3 GeV, InterstageBasic, stage 24)
# WARNING: 0.9% of driver particles were energy depleted.
# Tracking element #50 (s = 840.4 m, -2.70 nC, 630.2 GeV, StageNonlinear1D, stage 25)
# Tracking element #51 (s = 878.4 m, -2.70 nC, 630.2 GeV, InterstageBasic, stage 25)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #52 (s = 882.6 m, -2.70 nC, 654.6 GeV, StageNonlinear1D, stage 26)
# Tracking element #53 (s = 921.3 m, -2.70 nC, 654.6 GeV, InterstageBasic, stage 26)
# Tracking element #54 (s = 925.6 m, -2.70 nC, 678.7 GeV, StageNonlinear1D, stage 27)
# Tracking element #55 (s = 965.0 m, -2.70 nC, 678.7 GeV, InterstageBasic, stage 27)
# WARNING: 19.6% of driver particles were energy depleted.
# Tracking element #56 (s = 969.2 m, -2.70 nC, 703.5 GeV, StageNonlinear1D, stage 28)
# Tracking element #57 (s = 1009.4 m, -2.70 nC, 703.5 GeV, InterstageBasic, stage 28)
# Tracking element #58 (s = 1013.6 m, -2.70 nC, 729.5 GeV, StageNonlinear1D, stage 29)
# Tracking element #59 (s = 1054.5 m, -2.70 nC, 729.5 GeV, InterstageBasic, stage 29)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #60 (s = 1058.7 m, -2.70 nC, 754.6 GeV, StageNonlinear1D, stage 30)
# Tracking element #61 (s = 1100.3 m, -2.70 nC, 754.6 GeV, InterstageBasic, stage 30)
# Tracking element #62 (s = 1104.5 m, -2.70 nC, 780.0 GeV, StageNonlinear1D, stage 31)
# Tracking element #63 (s = 1146.7 m, -2.70 nC, 780.0 GeV, InterstageBasic, stage 31)
# Tracking element #64 (s = 1151.0 m, -2.70 nC, 805.6 GeV, StageNonlinear1D, stage 32)
# Tracking element #65 (s = 1193.9 m, -2.70 nC, 805.6 GeV, InterstageBasic, stage 32)
# Tracking element #66 (s = 1198.1 m, -2.70 nC, 830.0 GeV, StageNonlinear1D, stage 33)
# Tracking element #67 (s = 1241.7 m, -2.70 nC, 830.0 GeV, InterstageBasic, stage 33)
# Tracking element #68 (s = 1245.9 m, -2.70 nC, 853.8 GeV, StageNonlinear1D, stage 34)
# Tracking element #69 (s = 1290.2 m, -2.70 nC, 853.8 GeV, InterstageBasic, stage 34)
# WARNING: 0.9% of driver particles were energy depleted.
# Tracking element #70 (s = 1294.4 m, -2.70 nC, 879.9 GeV, StageNonlinear1D, stage 35)
# Tracking element #71 (s = 1339.3 m, -2.70 nC, 879.9 GeV, InterstageBasic, stage 35)
# Tracking element #72 (s = 1343.5 m, -2.70 nC, 903.9 GeV, StageNonlinear1D, stage 36)
# Tracking element #73 (s = 1389.0 m, -2.70 nC, 903.9 GeV, InterstageBasic, stage 36)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #74 (s = 1393.3 m, -2.70 nC, 930.9 GeV, StageNonlinear1D, stage 37)
# Tracking element #75 (s = 1439.4 m, -2.70 nC, 930.9 GeV, InterstageBasic, stage 37)
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 955.4 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 955.4 GeV, InterstageBasic, stage 38)
# WARNING: 9.4% of driver particles were energy depleted.
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 980.2 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 980.2 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 1003.4 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 1003.4 GeV, InterstageBasic, stage 40)
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1026.7 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1026.7 GeV, InterstageBasic, stage 41)
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1049.9 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1049.9 GeV, InterstageBasic, stage 42)
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1074.2 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1074.2 GeV, InterstageBasic, stage 43)
# WARNING: 18.4% of driver particles were energy depleted.
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1099.8 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1099.8 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1124.1 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1124.1 GeV, InterstageBasic, stage 45)
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1149.2 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1149.2 GeV, InterstageBasic, stage 46)
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1174.2 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1174.2 GeV, InterstageBasic, stage 47)
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1198.7 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1198.7 GeV, InterstageBasic, stage 48)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1223.6 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1223.6 GeV, InterstageBasic, stage 49)
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1249.2 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1249.2 GeV, InterstageBasic, stage 50)
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1275.1 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1275.1 GeV, InterstageBasic, stage 51)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1300.2 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1300.2 GeV, InterstageBasic, stage 52)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1323.9 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1323.9 GeV, InterstageBasic, stage 53)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1347.1 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1347.1 GeV, InterstageBasic, stage 54)
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1372.7 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1372.7 GeV, InterstageBasic, stage 55)
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1398.8 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1398.8 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1422.1 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1422.1 GeV, InterstageBasic, stage 57)
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1447.8 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1447.8 GeV, InterstageBasic, stage 58)
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1473.2 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1473.2 GeV, InterstageBasic, stage 59)
# WARNING: 0.5% of driver particles were energy depleted.
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1497.6 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1497.6 GeV, BeamDeliverySystemBasic, stage 60)
# >> LINAC #2
# >> SHOT #1
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# WARNING: 2.3% of driver particles were energy depleted.
# Tracking element #2 (s = 124.2 m, -2.70 nC, 27.1 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 27.1 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 52.7 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 52.7 GeV, InterstageBasic, stage 2)
# Tracking element #6 (s = 151.8 m, -2.70 nC, 76.6 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 76.6 GeV, InterstageBasic, stage 3)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #8 (s = 169.4 m, -2.70 nC, 102.7 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 102.7 GeV, InterstageBasic, stage 4)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #10 (s = 189.0 m, -2.70 nC, 128.6 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 128.6 GeV, InterstageBasic, stage 5)
# WARNING: 0.2% of driver particles were energy depleted.
# Tracking element #12 (s = 210.4 m, -2.70 nC, 154.0 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 154.0 GeV, InterstageBasic, stage 6)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #14 (s = 233.4 m, -2.70 nC, 181.7 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 181.7 GeV, InterstageBasic, stage 7)
# Tracking element #16 (s = 257.8 m, -2.70 nC, 208.8 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 208.8 GeV, InterstageBasic, stage 8)
# Tracking element #18 (s = 283.6 m, -2.70 nC, 237.0 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 237.0 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 261.6 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 261.6 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 286.5 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 286.5 GeV, InterstageBasic, stage 11)
# Tracking element #24 (s = 368.6 m, -2.70 nC, 314.0 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 314.0 GeV, InterstageBasic, stage 12)
# Tracking element #26 (s = 399.2 m, -2.70 nC, 339.2 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 339.2 GeV, InterstageBasic, stage 13)
# Tracking element #28 (s = 430.8 m, -2.70 nC, 364.4 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 364.4 GeV, InterstageBasic, stage 14)
# Tracking element #30 (s = 463.5 m, -2.70 nC, 387.9 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 387.9 GeV, InterstageBasic, stage 15)
# WARNING: 5.0% of driver particles were energy depleted.
# Tracking element #32 (s = 497.2 m, -2.70 nC, 413.1 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 413.1 GeV, InterstageBasic, stage 16)
# Tracking element #34 (s = 531.9 m, -2.70 nC, 437.4 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 437.4 GeV, InterstageBasic, stage 17)
# Tracking element #36 (s = 567.4 m, -2.70 nC, 460.8 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 460.8 GeV, InterstageBasic, stage 18)
# Tracking element #38 (s = 603.9 m, -2.70 nC, 485.0 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 485.0 GeV, InterstageBasic, stage 19)
# Tracking element #40 (s = 641.3 m, -2.70 nC, 508.8 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 508.8 GeV, InterstageBasic, stage 20)
# Tracking element #42 (s = 679.5 m, -2.70 nC, 532.8 GeV, StageNonlinear1D, stage 21)
# Tracking element #43 (s = 714.3 m, -2.70 nC, 532.8 GeV, InterstageBasic, stage 21)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #44 (s = 718.5 m, -2.70 nC, 556.3 GeV, StageNonlinear1D, stage 22)
# Tracking element #45 (s = 754.1 m, -2.70 nC, 556.3 GeV, InterstageBasic, stage 22)
# Tracking element #46 (s = 758.4 m, -2.70 nC, 578.8 GeV, StageNonlinear1D, stage 23)
# Tracking element #47 (s = 794.8 m, -2.70 nC, 578.8 GeV, InterstageBasic, stage 23)
# Tracking element #48 (s = 799.0 m, -2.70 nC, 603.4 GeV, StageNonlinear1D, stage 24)
# Tracking element #49 (s = 836.2 m, -2.70 nC, 603.4 GeV, InterstageBasic, stage 24)
# Tracking element #50 (s = 840.4 m, -2.70 nC, 626.5 GeV, StageNonlinear1D, stage 25)
# Tracking element #51 (s = 878.4 m, -2.70 nC, 626.5 GeV, InterstageBasic, stage 25)
# Tracking element #52 (s = 882.6 m, -2.70 nC, 649.8 GeV, StageNonlinear1D, stage 26)
# Tracking element #53 (s = 921.3 m, -2.70 nC, 649.8 GeV, InterstageBasic, stage 26)
# WARNING: 8.8% of driver particles were energy depleted.
# Tracking element #54 (s = 925.6 m, -2.70 nC, 671.5 GeV, StageNonlinear1D, stage 27)
# Tracking element #55 (s = 965.0 m, -2.70 nC, 671.5 GeV, InterstageBasic, stage 27)
# Tracking element #56 (s = 969.2 m, -2.70 nC, 692.8 GeV, StageNonlinear1D, stage 28)
# Tracking element #57 (s = 1009.4 m, -2.70 nC, 692.8 GeV, InterstageBasic, stage 28)
# Tracking element #58 (s = 1013.6 m, -2.70 nC, 715.1 GeV, StageNonlinear1D, stage 29)
# Tracking element #59 (s = 1054.5 m, -2.70 nC, 715.1 GeV, InterstageBasic, stage 29)
# Tracking element #60 (s = 1058.7 m, -2.70 nC, 738.4 GeV, StageNonlinear1D, stage 30)
# Tracking element #61 (s = 1100.3 m, -2.70 nC, 738.4 GeV, InterstageBasic, stage 30)
# Tracking element #62 (s = 1104.5 m, -2.70 nC, 762.3 GeV, StageNonlinear1D, stage 31)
# Tracking element #63 (s = 1146.7 m, -2.70 nC, 762.3 GeV, InterstageBasic, stage 31)
# Tracking element #64 (s = 1151.0 m, -2.70 nC, 786.8 GeV, StageNonlinear1D, stage 32)
# Tracking element #65 (s = 1193.9 m, -2.70 nC, 786.8 GeV, InterstageBasic, stage 32)
# Tracking element #66 (s = 1198.1 m, -2.70 nC, 810.2 GeV, StageNonlinear1D, stage 33)
# Tracking element #67 (s = 1241.7 m, -2.70 nC, 810.2 GeV, InterstageBasic, stage 33)
# Tracking element #68 (s = 1245.9 m, -2.70 nC, 836.4 GeV, StageNonlinear1D, stage 34)
# Tracking element #69 (s = 1290.2 m, -2.70 nC, 836.4 GeV, InterstageBasic, stage 34)
# Tracking element #70 (s = 1294.4 m, -2.70 nC, 859.6 GeV, StageNonlinear1D, stage 35)
# Tracking element #71 (s = 1339.3 m, -2.70 nC, 859.6 GeV, InterstageBasic, stage 35)
# WARNING: 5.6% of driver particles were energy depleted.
# Tracking element #72 (s = 1343.5 m, -2.70 nC, 883.0 GeV, StageNonlinear1D, stage 36)
# Tracking element #73 (s = 1389.0 m, -2.70 nC, 883.0 GeV, InterstageBasic, stage 36)
# Tracking element #74 (s = 1393.3 m, -2.70 nC, 908.2 GeV, StageNonlinear1D, stage 37)
# Tracking element #75 (s = 1439.4 m, -2.70 nC, 908.2 GeV, InterstageBasic, stage 37)
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 931.8 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 931.8 GeV, InterstageBasic, stage 38)
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 955.6 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 955.6 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 980.2 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 980.2 GeV, InterstageBasic, stage 40)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1005.6 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1005.6 GeV, InterstageBasic, stage 41)
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1029.8 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1029.8 GeV, InterstageBasic, stage 42)
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1056.4 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1056.4 GeV, InterstageBasic, stage 43)
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1082.5 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1082.5 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1107.9 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1107.9 GeV, InterstageBasic, stage 45)
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1132.4 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1132.4 GeV, InterstageBasic, stage 46)
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1157.4 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1157.4 GeV, InterstageBasic, stage 47)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1181.1 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1181.1 GeV, InterstageBasic, stage 48)
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1204.6 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1204.6 GeV, InterstageBasic, stage 49)
# WARNING: 35.2% of driver particles were energy depleted.
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1228.9 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1228.9 GeV, InterstageBasic, stage 50)
# WARNING: 7.6% of driver particles were energy depleted.
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1253.3 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1253.3 GeV, InterstageBasic, stage 51)
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1277.4 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1277.4 GeV, InterstageBasic, stage 52)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1302.2 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1302.2 GeV, InterstageBasic, stage 53)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1326.6 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1326.6 GeV, InterstageBasic, stage 54)
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1353.2 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1353.2 GeV, InterstageBasic, stage 55)
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1378.4 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1378.4 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1404.1 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1404.1 GeV, InterstageBasic, stage 57)
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1431.3 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1431.3 GeV, InterstageBasic, stage 58)
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1456.0 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1456.0 GeV, InterstageBasic, stage 59)
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1482.8 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1482.8 GeV, BeamDeliverySystemBasic, stage 60)
# >> SHOT #2
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# Tracking element #2 (s = 124.2 m, -2.70 nC, 29.2 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 29.2 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 53.4 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 53.4 GeV, InterstageBasic, stage 2)
# Tracking element #6 (s = 151.8 m, -2.70 nC, 76.4 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 76.4 GeV, InterstageBasic, stage 3)
# Tracking element #8 (s = 169.4 m, -2.70 nC, 99.1 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 99.1 GeV, InterstageBasic, stage 4)
# Tracking element #10 (s = 189.0 m, -2.70 nC, 122.4 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 122.4 GeV, InterstageBasic, stage 5)
# Tracking element #12 (s = 210.4 m, -2.70 nC, 144.7 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 144.7 GeV, InterstageBasic, stage 6)
# WARNING: 4.5% of driver particles were energy depleted.
# Tracking element #14 (s = 233.4 m, -2.70 nC, 167.8 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 167.8 GeV, InterstageBasic, stage 7)
# Tracking element #16 (s = 257.8 m, -2.70 nC, 191.1 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 191.1 GeV, InterstageBasic, stage 8)
# Tracking element #18 (s = 283.6 m, -2.70 nC, 214.9 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 214.9 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 238.1 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 238.1 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 263.8 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 263.8 GeV, InterstageBasic, stage 11)
# WARNING: 4.6% of driver particles were energy depleted.
# Tracking element #24 (s = 368.6 m, -2.70 nC, 289.8 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 289.8 GeV, InterstageBasic, stage 12)
# Tracking element #26 (s = 399.2 m, -2.70 nC, 316.5 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 316.5 GeV, InterstageBasic, stage 13)
# Tracking element #28 (s = 430.8 m, -2.70 nC, 342.8 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 342.8 GeV, InterstageBasic, stage 14)
# Tracking element #30 (s = 463.5 m, -2.70 nC, 369.7 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 369.7 GeV, InterstageBasic, stage 15)
# Tracking element #32 (s = 497.2 m, -2.70 nC, 396.6 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 396.6 GeV, InterstageBasic, stage 16)
# Tracking element #34 (s = 531.9 m, -2.70 nC, 423.1 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 423.1 GeV, InterstageBasic, stage 17)
# WARNING: 7.2% of driver particles were energy depleted.
# Tracking element #36 (s = 567.4 m, -2.70 nC, 449.0 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 449.0 GeV, InterstageBasic, stage 18)
# Tracking element #38 (s = 603.9 m, -2.70 nC, 475.5 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 475.5 GeV, InterstageBasic, stage 19)
# Tracking element #40 (s = 641.3 m, -2.70 nC, 502.0 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 502.0 GeV, InterstageBasic, stage 20)
# Tracking element #42 (s = 679.5 m, -2.70 nC, 530.4 GeV, StageNonlinear1D, stage 21)
# ...
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 974.7 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 974.7 GeV, InterstageBasic, stage 38)
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 999.5 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 999.5 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 1022.6 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 1022.6 GeV, InterstageBasic, stage 40)
# WARNING: 0.7% of driver particles were energy depleted.
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1046.2 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1046.2 GeV, InterstageBasic, stage 41)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1069.9 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1069.9 GeV, InterstageBasic, stage 42)
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1095.4 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1095.4 GeV, InterstageBasic, stage 43)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1119.6 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1119.6 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1147.3 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1147.3 GeV, InterstageBasic, stage 45)
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1172.7 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1172.7 GeV, InterstageBasic, stage 46)
# WARNING: 5.5% of driver particles were energy depleted.
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1197.3 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1197.3 GeV, InterstageBasic, stage 47)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1222.1 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1222.1 GeV, InterstageBasic, stage 48)
# WARNING: 12.6% of driver particles were energy depleted.
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1247.4 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1247.4 GeV, InterstageBasic, stage 49)
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1272.6 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1272.6 GeV, InterstageBasic, stage 50)
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1296.1 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1296.1 GeV, InterstageBasic, stage 51)
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1320.3 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1320.3 GeV, InterstageBasic, stage 52)
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1344.1 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1344.1 GeV, InterstageBasic, stage 53)
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1370.3 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1370.3 GeV, InterstageBasic, stage 54)
# WARNING: 0.4% of driver particles were energy depleted.
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1394.8 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1394.8 GeV, InterstageBasic, stage 55)
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1419.5 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1419.5 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1445.0 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1445.0 GeV, InterstageBasic, stage 57)
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1469.6 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1469.6 GeV, InterstageBasic, stage 58)
# WARNING: 1.5% of driver particles were energy depleted.
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1493.3 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1493.3 GeV, InterstageBasic, stage 59)
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1518.2 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1518.2 GeV, BeamDeliverySystemBasic, stage 60)
# >> SHOT #3
# Tracking element #1 (s = 120.0 m, -2.70 nC, 3.0 GeV, SourceBasic, stage 0)
# Tracking element #2 (s = 124.2 m, -2.70 nC, 26.2 GeV, StageNonlinear1D, stage 1)
# Tracking element #3 (s = 132.3 m, -2.70 nC, 26.2 GeV, InterstageBasic, stage 1)
# Tracking element #4 (s = 136.5 m, -2.70 nC, 52.2 GeV, StageNonlinear1D, stage 2)
# Tracking element #5 (s = 147.5 m, -2.70 nC, 52.2 GeV, InterstageBasic, stage 2)
# Tracking element #6 (s = 151.8 m, -2.70 nC, 78.7 GeV, StageNonlinear1D, stage 3)
# Tracking element #7 (s = 165.2 m, -2.70 nC, 78.7 GeV, InterstageBasic, stage 3)
# Tracking element #8 (s = 169.4 m, -2.70 nC, 102.9 GeV, StageNonlinear1D, stage 4)
# Tracking element #9 (s = 184.8 m, -2.70 nC, 102.9 GeV, InterstageBasic, stage 4)
# Tracking element #10 (s = 189.0 m, -2.70 nC, 128.6 GeV, StageNonlinear1D, stage 5)
# Tracking element #11 (s = 206.1 m, -2.70 nC, 128.6 GeV, InterstageBasic, stage 5)
# Tracking element #12 (s = 210.4 m, -2.70 nC, 154.5 GeV, StageNonlinear1D, stage 6)
# Tracking element #13 (s = 229.1 m, -2.70 nC, 154.5 GeV, InterstageBasic, stage 6)
# Tracking element #14 (s = 233.4 m, -2.70 nC, 178.4 GeV, StageNonlinear1D, stage 7)
# Tracking element #15 (s = 253.6 m, -2.70 nC, 178.4 GeV, InterstageBasic, stage 7)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #16 (s = 257.8 m, -2.70 nC, 204.2 GeV, StageNonlinear1D, stage 8)
# Tracking element #17 (s = 279.4 m, -2.70 nC, 204.2 GeV, InterstageBasic, stage 8)
# Tracking element #18 (s = 283.6 m, -2.70 nC, 229.2 GeV, StageNonlinear1D, stage 9)
# Tracking element #19 (s = 306.5 m, -2.70 nC, 229.2 GeV, InterstageBasic, stage 9)
# Tracking element #20 (s = 310.8 m, -2.70 nC, 253.8 GeV, StageNonlinear1D, stage 10)
# Tracking element #21 (s = 334.8 m, -2.70 nC, 253.8 GeV, InterstageBasic, stage 10)
# Tracking element #22 (s = 339.1 m, -2.70 nC, 277.2 GeV, StageNonlinear1D, stage 11)
# Tracking element #23 (s = 364.3 m, -2.70 nC, 277.2 GeV, InterstageBasic, stage 11)
# WARNING: 1.1% of driver particles were energy depleted.
# Tracking element #24 (s = 368.6 m, -2.70 nC, 302.3 GeV, StageNonlinear1D, stage 12)
# Tracking element #25 (s = 394.9 m, -2.70 nC, 302.3 GeV, InterstageBasic, stage 12)
# Tracking element #26 (s = 399.2 m, -2.70 nC, 326.9 GeV, StageNonlinear1D, stage 13)
# Tracking element #27 (s = 426.6 m, -2.70 nC, 326.9 GeV, InterstageBasic, stage 13)
# Tracking element #28 (s = 430.8 m, -2.70 nC, 352.1 GeV, StageNonlinear1D, stage 14)
# Tracking element #29 (s = 459.3 m, -2.70 nC, 352.1 GeV, InterstageBasic, stage 14)
# WARNING: 3.3% of driver particles were energy depleted.
# Tracking element #30 (s = 463.5 m, -2.70 nC, 377.8 GeV, StageNonlinear1D, stage 15)
# Tracking element #31 (s = 493.0 m, -2.70 nC, 377.8 GeV, InterstageBasic, stage 15)
# Tracking element #32 (s = 497.2 m, -2.70 nC, 404.4 GeV, StageNonlinear1D, stage 16)
# Tracking element #33 (s = 527.6 m, -2.70 nC, 404.4 GeV, InterstageBasic, stage 16)
# Tracking element #34 (s = 531.9 m, -2.70 nC, 429.8 GeV, StageNonlinear1D, stage 17)
# Tracking element #35 (s = 563.2 m, -2.70 nC, 429.8 GeV, InterstageBasic, stage 17)
# Tracking element #36 (s = 567.4 m, -2.70 nC, 455.2 GeV, StageNonlinear1D, stage 18)
# Tracking element #37 (s = 599.7 m, -2.70 nC, 455.2 GeV, InterstageBasic, stage 18)
# WARNING: 12.0% of driver particles were energy depleted.
# Tracking element #38 (s = 603.9 m, -2.70 nC, 478.4 GeV, StageNonlinear1D, stage 19)
# Tracking element #39 (s = 637.0 m, -2.70 nC, 478.4 GeV, InterstageBasic, stage 19)
# Tracking element #40 (s = 641.3 m, -2.70 nC, 504.4 GeV, StageNonlinear1D, stage 20)
# Tracking element #41 (s = 675.2 m, -2.70 nC, 504.4 GeV, InterstageBasic, stage 20)
# Tracking element #42 (s = 679.5 m, -2.70 nC, 529.3 GeV, StageNonlinear1D, stage 21)
# Tracking element #43 (s = 714.3 m, -2.70 nC, 529.3 GeV, InterstageBasic, stage 21)
# Tracking element #44 (s = 718.5 m, -2.70 nC, 555.8 GeV, StageNonlinear1D, stage 22)
# Tracking element #45 (s = 754.1 m, -2.70 nC, 555.8 GeV, InterstageBasic, stage 22)
# Tracking element #46 (s = 758.4 m, -2.70 nC, 582.4 GeV, StageNonlinear1D, stage 23)
# Tracking element #47 (s = 794.8 m, -2.70 nC, 582.4 GeV, InterstageBasic, stage 23)
# Tracking element #48 (s = 799.0 m, -2.70 nC, 608.0 GeV, StageNonlinear1D, stage 24)
# Tracking element #49 (s = 836.2 m, -2.70 nC, 608.0 GeV, InterstageBasic, stage 24)
# Tracking element #50 (s = 840.4 m, -2.70 nC, 633.2 GeV, StageNonlinear1D, stage 25)
# Tracking element #51 (s = 878.4 m, -2.70 nC, 633.2 GeV, InterstageBasic, stage 25)
# Tracking element #52 (s = 882.6 m, -2.70 nC, 657.0 GeV, StageNonlinear1D, stage 26)
# Tracking element #53 (s = 921.3 m, -2.70 nC, 657.0 GeV, InterstageBasic, stage 26)
# Tracking element #54 (s = 925.6 m, -2.70 nC, 681.8 GeV, StageNonlinear1D, stage 27)
# Tracking element #55 (s = 965.0 m, -2.70 nC, 681.8 GeV, InterstageBasic, stage 27)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #56 (s = 969.2 m, -2.70 nC, 707.1 GeV, StageNonlinear1D, stage 28)
# Tracking element #57 (s = 1009.4 m, -2.70 nC, 707.1 GeV, InterstageBasic, stage 28)
# WARNING: 22.2% of driver particles were energy depleted.
# Tracking element #58 (s = 1013.6 m, -2.70 nC, 732.6 GeV, StageNonlinear1D, stage 29)
# Tracking element #59 (s = 1054.5 m, -2.70 nC, 732.6 GeV, InterstageBasic, stage 29)
# Tracking element #60 (s = 1058.7 m, -2.70 nC, 758.1 GeV, StageNonlinear1D, stage 30)
# Tracking element #61 (s = 1100.3 m, -2.70 nC, 758.1 GeV, InterstageBasic, stage 30)
# Tracking element #62 (s = 1104.5 m, -2.70 nC, 782.3 GeV, StageNonlinear1D, stage 31)
# Tracking element #63 (s = 1146.7 m, -2.70 nC, 782.3 GeV, InterstageBasic, stage 31)
# Tracking element #64 (s = 1151.0 m, -2.70 nC, 806.8 GeV, StageNonlinear1D, stage 32)
# Tracking element #65 (s = 1193.9 m, -2.70 nC, 806.8 GeV, InterstageBasic, stage 32)
# Tracking element #66 (s = 1198.1 m, -2.70 nC, 832.0 GeV, StageNonlinear1D, stage 33)
# Tracking element #67 (s = 1241.7 m, -2.70 nC, 832.0 GeV, InterstageBasic, stage 33)
# WARNING: 0.6% of driver particles were energy depleted.
# Tracking element #68 (s = 1245.9 m, -2.70 nC, 856.8 GeV, StageNonlinear1D, stage 34)
# Tracking element #69 (s = 1290.2 m, -2.70 nC, 856.8 GeV, InterstageBasic, stage 34)
# Tracking element #70 (s = 1294.4 m, -2.70 nC, 882.3 GeV, StageNonlinear1D, stage 35)
# Tracking element #71 (s = 1339.3 m, -2.70 nC, 882.3 GeV, InterstageBasic, stage 35)
# Tracking element #72 (s = 1343.5 m, -2.70 nC, 909.2 GeV, StageNonlinear1D, stage 36)
# Tracking element #73 (s = 1389.0 m, -2.70 nC, 909.2 GeV, InterstageBasic, stage 36)
# Tracking element #74 (s = 1393.3 m, -2.70 nC, 934.0 GeV, StageNonlinear1D, stage 37)
# Tracking element #75 (s = 1439.4 m, -2.70 nC, 934.0 GeV, InterstageBasic, stage 37)
# WARNING: 6.1% of driver particles were energy depleted.
# Tracking element #76 (s = 1443.6 m, -2.70 nC, 957.5 GeV, StageNonlinear1D, stage 38)
# Tracking element #77 (s = 1490.4 m, -2.70 nC, 957.5 GeV, InterstageBasic, stage 38)
# Tracking element #78 (s = 1494.6 m, -2.70 nC, 983.1 GeV, StageNonlinear1D, stage 39)
# Tracking element #79 (s = 1542.0 m, -2.70 nC, 983.1 GeV, InterstageBasic, stage 39)
# Tracking element #80 (s = 1546.2 m, -2.70 nC, 1007.2 GeV, StageNonlinear1D, stage 40)
# Tracking element #81 (s = 1594.2 m, -2.70 nC, 1007.2 GeV, InterstageBasic, stage 40)
# Tracking element #82 (s = 1598.4 m, -2.70 nC, 1032.2 GeV, StageNonlinear1D, stage 41)
# Tracking element #83 (s = 1647.0 m, -2.70 nC, 1032.2 GeV, InterstageBasic, stage 41)
# WARNING: 31.8% of driver particles were energy depleted.
# Tracking element #84 (s = 1651.2 m, -2.70 nC, 1054.6 GeV, StageNonlinear1D, stage 42)
# Tracking element #85 (s = 1700.3 m, -2.70 nC, 1054.6 GeV, InterstageBasic, stage 42)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #86 (s = 1704.6 m, -2.70 nC, 1079.6 GeV, StageNonlinear1D, stage 43)
# Tracking element #87 (s = 1754.3 m, -2.70 nC, 1079.6 GeV, InterstageBasic, stage 43)
# WARNING: 1.1% of driver particles were energy depleted.
# Tracking element #88 (s = 1758.5 m, -2.70 nC, 1103.0 GeV, StageNonlinear1D, stage 44)
# Tracking element #89 (s = 1808.8 m, -2.70 nC, 1103.0 GeV, InterstageBasic, stage 44)
# Tracking element #90 (s = 1813.1 m, -2.70 nC, 1127.2 GeV, StageNonlinear1D, stage 45)
# Tracking element #91 (s = 1863.9 m, -2.70 nC, 1127.2 GeV, InterstageBasic, stage 45)
# Tracking element #92 (s = 1868.2 m, -2.70 nC, 1152.1 GeV, StageNonlinear1D, stage 46)
# Tracking element #93 (s = 1919.6 m, -2.70 nC, 1152.1 GeV, InterstageBasic, stage 46)
# Tracking element #94 (s = 1923.8 m, -2.70 nC, 1177.3 GeV, StageNonlinear1D, stage 47)
# Tracking element #95 (s = 1975.8 m, -2.70 nC, 1177.3 GeV, InterstageBasic, stage 47)
# Tracking element #96 (s = 1980.0 m, -2.70 nC, 1201.8 GeV, StageNonlinear1D, stage 48)
# Tracking element #97 (s = 2032.5 m, -2.70 nC, 1201.8 GeV, InterstageBasic, stage 48)
# Tracking element #98 (s = 2036.8 m, -2.70 nC, 1227.2 GeV, StageNonlinear1D, stage 49)
# Tracking element #99 (s = 2089.9 m, -2.70 nC, 1227.2 GeV, InterstageBasic, stage 49)
# Tracking element #100 (s = 2094.1 m, -2.70 nC, 1252.4 GeV, StageNonlinear1D, stage 50)
# Tracking element #101 (s = 2147.7 m, -2.70 nC, 1252.4 GeV, InterstageBasic, stage 50)
# Tracking element #102 (s = 2151.9 m, -2.70 nC, 1277.7 GeV, StageNonlinear1D, stage 51)
# Tracking element #103 (s = 2206.1 m, -2.70 nC, 1277.7 GeV, InterstageBasic, stage 51)
# Tracking element #104 (s = 2210.3 m, -2.70 nC, 1301.6 GeV, StageNonlinear1D, stage 52)
# Tracking element #105 (s = 2265.0 m, -2.70 nC, 1301.6 GeV, InterstageBasic, stage 52)
# Tracking element #106 (s = 2269.2 m, -2.70 nC, 1325.2 GeV, StageNonlinear1D, stage 53)
# Tracking element #107 (s = 2324.4 m, -2.70 nC, 1325.2 GeV, InterstageBasic, stage 53)
# Tracking element #108 (s = 2328.6 m, -2.70 nC, 1349.2 GeV, StageNonlinear1D, stage 54)
# Tracking element #109 (s = 2384.3 m, -2.70 nC, 1349.2 GeV, InterstageBasic, stage 54)
# Tracking element #110 (s = 2388.6 m, -2.70 nC, 1372.8 GeV, StageNonlinear1D, stage 55)
# Tracking element #111 (s = 2444.8 m, -2.70 nC, 1372.8 GeV, InterstageBasic, stage 55)
# Tracking element #112 (s = 2449.0 m, -2.70 nC, 1397.1 GeV, StageNonlinear1D, stage 56)
# Tracking element #113 (s = 2505.7 m, -2.70 nC, 1397.1 GeV, InterstageBasic, stage 56)
# Tracking element #114 (s = 2510.0 m, -2.70 nC, 1419.7 GeV, StageNonlinear1D, stage 57)
# Tracking element #115 (s = 2567.2 m, -2.70 nC, 1419.7 GeV, InterstageBasic, stage 57)
# WARNING: 0.1% of driver particles were energy depleted.
# Tracking element #116 (s = 2571.4 m, -2.70 nC, 1445.0 GeV, StageNonlinear1D, stage 58)
# Tracking element #117 (s = 2629.1 m, -2.70 nC, 1445.0 GeV, InterstageBasic, stage 58)
# Tracking element #118 (s = 2633.4 m, -2.70 nC, 1469.2 GeV, StageNonlinear1D, stage 59)
# Tracking element #119 (s = 2691.6 m, -2.70 nC, 1469.2 GeV, InterstageBasic, stage 59)
# Tracking element #120 (s = 2695.8 m, -2.70 nC, 1494.2 GeV, StageNonlinear1D, stage 60)
# Tracking element #121 (s = 5454.3 m, -2.70 nC, 1494.2 GeV, BeamDeliverySystemBasic, stage 60)
# >> INTERACTION POINT
# >> EVENT #1: Luminosity (full/peak/geom.): 0.27 / 0.09 / 0.26 μb^-1
# >> EVENT #2: Luminosity (full/peak/geom.): 0.21 / 0.05 / 0.21 μb^-1
# >> EVENT #3: Luminosity (full/peak/geom.): 0.16 / 0.04 / 0.19 μb^-1
# >> EVENT #4: Luminosity (full/peak/geom.): 0.7 / 0.29 / 0.68 μb^-1
# >> EVENT #5: Luminosity (full/peak/geom.): 0.98 / 0.39 / 0.92 μb^-1
# >> EVENT #6: Luminosity (full/peak/geom.): 0.85 / 0.32 / 0.82 μb^-1
# >> EVENT #7: Luminosity (full/peak/geom.): 0.48 / 0.18 / 0.46 μb^-1
# >> EVENT #8: Luminosity (full/peak/geom.): 0.23 / 0.09 / 0.24 μb^-1
# >> EVENT #9: Luminosity (full/peak/geom.): 0.24 / 0.062 / 0.23 μb^-1
# COST: 2.49 (construction) + 11.35 (running) = 13.83 billion LCU
